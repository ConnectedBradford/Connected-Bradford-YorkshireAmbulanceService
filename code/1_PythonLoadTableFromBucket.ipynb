# %%
from google.cloud import bigquery
from google.cloud.bigquery import LoadJobConfig
from google.cloud.bigquery import SchemaField

client = bigquery.Client()
dataset_ref = client.dataset('CB_MYSPACE_JDB')

# %%
## Create the table tbl_YAS_IUC

schema = [
bigquery.SchemaField('CaseRef', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CaseNo', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Receiving_Call_Centre', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('999_to_111', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('999_CAD_Number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Commenced_Date_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NHS_Number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Age', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Patient_Home_Postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Patient_Current_Postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CCG_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GP_Surgery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GP_Surgery_ID', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('First_Party_Caller', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Case_Type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Highest_Skillset', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_1_Triage_Start_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_1_Triage_End_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_1_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_2_Triage_Start_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_2_Triage_End_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_2_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_3_Triage_Start_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_3_Triage_End_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Handler_3_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_1_Triage_Start_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_1_Triage_End_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_1_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_2_Triage_Start_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_2_Triage_End_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_2_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_3_Triage_Start_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_3_Triage_End_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Advisor_3_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Non-Clinical_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Non-Clinical_Dx_Description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NHS_England_MDS_Non-Clinical_Dx_Group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IUC_ADC_Non-Clinical_Dx_Group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Clinical_Dx_Description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NHS_England_MDS_Clinical_Dx_Group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IUC_ADC_Clinical_Dx_Group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Final_Dx_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Final_Dx_Description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('NHS_England_MDS_Final_Dx_Group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('IUC_ADC_Final_Dx_Group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('First_Pathway_Selected', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Final_Symptom_Group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Final_Symptom_Discriminator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CallBackRequired', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Back_Start_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Called_Back', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('First_Attempted_Callback_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Call_Back_End_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Total_Attempted_Callbacks', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Referral_Service', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Referral_Service_Type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Warm_Transferred', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Secure_Information_Transfer_ITK_or_E-Mail', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Direct_Booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Direct_Booking_Service', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Appointment_Time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Rejected_Service', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Rejected_Service_Reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('LoadedToGCP', 'STRING', mode='NULLABLE')
]

table_ref = dataset_ref.table('tbl_YAS_IUC_v4')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
#table = client.create_table(table)  # API request

## Loading data for tbl_YAS_IUC_V4

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_YAS_IUC.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# Loaded 5169730 rows.
